# %%
import pandas as pd

# %%
npr = pd.read_csv("C:\\Users\\fabia\\Desktop\\modelos\\NewsF.csv",sep=";")

# %%
npr.head()
# Out:
#    Unnamed: 0      Type                                               News
# 0           0  Business  Ad sales boost Time Warner profit\n\nQuarterly...
# 1           1  Business  Dollar gains on Greenspan speech\n\nThe dollar...
# 2           2  Business  Yukos unit buyer faces loan claim\n\nThe owner...
# 3           3  Business  High fuel prices hit BA's profits\n\nBritish A...
# 4           4  Business  Pernod takeover talk lifts Domecq\n\nShares in...

# %% [markdown]
# # Preprocesamiento

# %%
#Vectorizacion
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=0.9,min_df=2,stop_words='english')
dtm = cv.fit_transform(npr['News'])

# %%
#Matriz de vocavulario con las repeticiones por termino
dtm
# Out:
# <2225x17473 sparse matrix of type '<class 'numpy.int64'>'
# 	with 310493 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # SVD Transformacion

# %%
from sklearn.decomposition import TruncatedSVD
#Representacion de documentos y terminos en vectores
#svd_model = TruncatedSVD(n_components=5,algorithm='randomized',n_iter=100,random_state=42)
svd_model = TruncatedSVD(n_components=5,random_state=42,n_iter=200,algorithm="randomized")
svd_model.fit(dtm)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=5, n_iter=200,
#        random_state=42, tol=0.0)

# %%
#svd_model.components_
svd_model.
# Out:
# array([0.02989553, 0.02784633, 0.0203218 , 0.01494303, 0.01494194])

# %%
#Obtener los temas correspondientes y las palabras relacionadas con cada tema
for index,topic in enumerate(svd_model.components_):
    print(f'The top 15 words for topic # {index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# The top 15 words for topic # 0
# ['told', 'world', 'just', 'like', 'labour', 'years', 'music', 'uk', 'time', 'government', 'year', 'new', 'people', 'mr', 'said']
#
#
# The top 15 words for topic # 1
# ['robbie', 'think', 'game', 'year', 'urban', 'awards', 'like', 'people', 'won', 'angels', '25', 'years', 'song', 'music', 'best']
#
#
# The top 15 words for topic # 2
# ['robbie', 'british', 'government', '25', 'angels', 'years', 'music', 'brown', 'party', 'election', 'blair', 'labour', 'song', 'best', 'mr']
#
#
# The top 15 words for topic # 3
# ['black', 'tv', 'users', 'phones', 'services', 'use', 'like', 'digital', 'phone', 'technology', 'mr', 'urban', 'mobile', 'music', 'people']
#
#
# The top 15 words for topic # 4
# ['nadal', 'gaming', 'half', 'ireland', 'playing', 'just', 'roddick', 'wales', 'play', 'england', 'world', 'new', 'time', 'games', 'game']

# %% [markdown]
# # Busqueda de cuadricula para ver con cuantos componentes es mejor
# (no se puede,ya que no entrega score)

# %%
#parametros de busqueda
search_params = {'n_components':[5,10,15],"n_iter":[200],"random_state":[42]}

# %%
#Definiendo modelo
svd = TruncatedSVD()

# %%
from sklearn.model_selection import GridSearchCV
#Iniciando GridSearchCV
model = GridSearchCV(svd,param_grid=search_params)

# %%
#Hacer busqueda de cuadricula
#model.fit(dtm)

# %% [markdown]
# # Tema dominante en el texto

# %%
#Nombre de columnas
topicnames = []
for i in range(int(svd_model.n_components)):
    name='Topic'+str(i)
    topicnames.append(name)

# %%
#nombre de indices
docnames = []
#for i in range(len(cv.get_feature_names())):
for i in range(2225):
    docnames.append('Doc'+str(i))

# %%
import numpy as np
svc_output = svd_model.transform(dtm)
#Creando un dataframe en pandas
df_document_topic=pd.DataFrame(np.round(svc_output,2),columns=topicnames,index=docnames)

# %%
# Obtener tema dominante para cada documento
dominant_topic=np.argmax(df_document_topic.values,axis=1)
df_document_topic['dominant_topic']=dominant_topic

# %%
#Estilando
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# %%
#Aplicando estilo
df_document_topic=df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topic
# Out:
# <style  type="text/css" >
#     #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row0_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row0_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row1_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_be6c46b4_42d9_11ea_a0aa_24b6fd067b28row1_col1 {
# ...

# %% [markdown]
# # Palabras claves del tema

# %%
# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(svd_model.components_)

# Assign Column and Index
df_topic_keywords.columns = cv.get_feature_names()
df_topic_keywords.index = topicnames

# View
df_topic_keywords.head()
# Out:
#               00       000      000m     000th       007        01      0100  \
# Topic0  0.000759  0.055270  0.001903  0.000106  0.000190  0.000328  0.000153
# Topic1  0.000520  0.006858  0.004554  0.000256  0.000750  0.000236  0.000365
# Topic2  0.000308 -0.032342 -0.000275 -0.000005  0.000237 -0.000209  0.000064
# Topic3  0.000822  0.002656 -0.007886 -0.000266 -0.001129 -0.000813 -0.000289
# Topic4  0.001572 -0.007200  0.007391  0.000032  0.000553  0.000282 -0.000446
#
#              011      0130        02  ...      zola    zombie   zombies  \
# Topic0  0.000072  0.000227  0.000072  ...  0.000131  0.000383  0.000796
# Topic1 -0.000010  0.000548  0.000161  ...  0.000148  0.000766 -0.000215
# Topic2 -0.000125  0.000356  0.000011  ... -0.000180 -0.000067 -0.001381
# Topic3 -0.000177 -0.001715 -0.000324  ... -0.000459  0.000842  0.000170
# Topic4 -0.000074 -0.000499  0.000302  ...  0.000495 -0.000577 -0.000646
#
# ...

# %% [markdown]
# # 15 palabras clave principales de cada tema

# %%
# Show top n keywords for each topic
def show_topics(cv=cv, svd_model=svd_model, n_words=20):
    keywords = np.array(cv.get_feature_names())
    topic_keywords = []
    for topic_weights in svd_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

topic_keywords = show_topics(cv=cv, svd_model=svd_model, n_words=15)        

# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#          Word 0 Word 1  Word 2  Word 3 Word 4      Word 5 Word 6   Word 7  \
# Topic 0    said     mr  people     new   year  government   time       uk
# Topic 1    best  music    song   years     25      angels    won   people
# Topic 2      mr   best    song  labour  blair    election  party    brown
# Topic 3  people  music  mobile   urban     mr  technology  phone  digital
# Topic 4    game  games    time     new  world     england   play    wales
#
#           Word 8  Word 9   Word 10  Word 11     Word 12  Word 13 Word 14
# Topic 0    music   years    labour     like        just    world    told
# Topic 1     like  awards     urban     year        game    think  robbie
# Topic 2    music   years    angels       25  government  british  robbie
# Topic 3     like     use  services   phones       users       tv   black
# Topic 4  roddick    just   playing  ireland        half   gaming   nadal

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from sompy.sompy import SOMFactory
from sklearn.datasets import fetch_california_housing

# %%
name=['Tech','Economy','Sport','Entertainment','Business']
#msz = calculate_msz(data)
sm = SOMFactory().build(svd_model.components_, normalization = 'var', initialization='random', component_names=name)
sm.train(n_job=-1, verbose=False, train_rough_len=2, train_finetune_len=5)

topographic_error = sm.calculate_topographic_error()
quantization_error = np.mean(sm._bmu[1])
print ("Topographic error = %s; Quantization error = %s" % (topographic_error, quantization_error))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-6ded9c4e976e> in <module>
#       1 name=['Tech','Economy','Sport','Entertainment','Business']
#       2 #msz = calculate_msz(data)
# ----> 3 sm = SOMFactory().build(svd_model.components_, normalization = 'var', initialization='random', component_names=name)
#       4 sm.train(n_job=-1, verbose=False, train_rough_len=2, train_finetune_len=5)
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\sompy\sompy.py in build(data, mapsize, mask, mapshape, lattice, normalization, initialization, neighborhood, training, name, component_names)
#      91         neighborhood_calculator = NeighborhoodFactory.build(neighborhood)
#      92         return SOM(data, neighborhood_calculator, normalizer, mapsize, mask,
# ---> 93                    mapshape, lattice, initialization, training, name, component_names)
#      94
# ...

# %%
from sompy.visualization.mapview import View2D
view2D  = View2D(10,10,"rand data",text_size=10)
view2D.show(sm, col_sz=4, which_dim="all", denormalize=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-54acfe2c60b1> in <module>
#       1 from sompy.visualization.mapview import View2D
#       2 view2D  = View2D(10,10,"rand data",text_size=10)
# ----> 3 view2D.show(sm, col_sz=4, which_dim="all", denormalize=True)
#
# NameError: name 'sm' is not defined

# %%
from sompy.visualization.bmuhits import BmuHitsView

vhts  = BmuHitsView(10,10,"Hits Map",text_size=7)
vhts.show(sm, anotate=True, onlyzeros=False, labelsize=10, cmap="autumn", logaritmic=False)
plt.show()
#cmap="Greys"

# %%
#Kmeans cluster
from sompy.visualization.hitmap import HitMapView
sm.cluster(5)
hits  = HitMapView(10,10,"Clustering",text_size=7)
a=hits.show(sm, labelsize=12)
